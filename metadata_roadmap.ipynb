# %% [markdown]
# ### Investigation on cell types of ROADMAP data

# %%
import pandas as pd
import numpy as np

# %%
path="../database/roadmap/Roadmap_metadata_summary_Table.tsv"

# %%
df_raw=pd.read_csv(path,delimiter="\t")

# %%
df_raw
# Out:
#                                               Comments Epigenome ID (EID)  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2    Outlier DNA methylation data due (older platform)               E017
# 3                                                  NaN               E002
# 4                                                  NaN               E008
# ..                                                 ...                ...
# 124                                                NaN               E125
# 125                                                NaN               E126
# 126                                                NaN               E127
# 127                                                NaN               E128
# 128                                                NaN               E129
#
#      ORDER       GROUP    COLOR Epigenome Mnemonic  Under Seq Quality Rating  \
# 0      NaN         NaN      NaN                NaN        NaN     Core Marks
# 1      NaN         NaN      NaN                NaN        NaN            NaN
# 2      1.0       IMR90  #E41A1C          LNG.IMR90        1.0              1
# 3      2.0         ESC  #924965            ESC.WA7       -1.0             -1
# 4      3.0         ESC  #924965             ESC.H9        1.0              1
# ..     ...         ...      ...                ...        ...            ...
# 124  123.0  ENCODE2012  #000000            BRN.NHA        1.0              1
# 125  124.0  ENCODE2012  #000000        SKIN.NHDFAD        1.0              1
# 126  125.0  ENCODE2012  #000000          SKIN.NHEK        0.0              1
# 127  126.0  ENCODE2012  #000000           LNG.NHLF        0.0              1
# 128  127.0  ENCODE2012  #000000         BONE.OSTEO        1.0              0
#
#      Auto Use Train (Core)  Manual Use Train (Core)  ...  \
# 0                      NaN                      NaN  ...
# 1                     94.0                     60.0  ...
# 2                      1.0                      1.0  ...
# 3                      0.0                      0.0  ...
# 4                      1.0                      1.0  ...
# ..                     ...                      ...  ...
# 124                    1.0                      1.0  ...
# 125                    1.0                      1.0  ...
# 126                    1.0                      1.0  ...
# 127                    1.0                      1.0  ...
# 128                    1.0                      0.0  ...
#
#                                      Pool Filenames.27  \
# 0                                             H3K79me2
# 1                                                   21
# 2    UCSD.IMR90.H3K79me2.LL238.bed.gz;UCSD.IMR90.H3...
# 3                                                  NaN
# 4    UCSD.H9.H3K79me2.AK143.bed.gz;UCSD.H9.H3K79me2...
# ..                                                 ...
# 124                                                  1
# 125                                                  1
# 126                                                  1
# 127                                                  1
# 128                                                  1
#
#                                      Pool Filenames.28  \
# 0                                             H2BK20ac
# 1                                                    3
# 2    UCSD.IMR90.H2BK20ac.YL07.bed.gz;UCSD.IMR90.H2B...
# 3                                                  NaN
# 4                        UCSD.H9.H2BK20ac.SK377.bed.gz
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
#
#                                      Pool Filenames.29  \
# 0                                              H3K56ac
# 1                                                    3
# 2    UCSD.IMR90.H3K56ac.YL05.bed.gz;UCSD.IMR90.H3K5...
# 3                                                  NaN
# 4    UCSD.H9.H3K56ac.SK279.bed.gz;UCSD.H9.H3K56ac.Y...
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
#
#                                      Pool Filenames.30  \
# 0                                             H4K20me1
# 1                                                   19
# 2    UCSD.IMR90.H4K20me1.YL59.bed.gz;UCSD.IMR90.H4K...
# 3                                                  NaN
# 4                        UCSD.H9.H4K20me1.SK286.bed.gz
# ..                                                 ...
# 124                                                  1
# 125                                                  1
# 126                                                  1
# 127                                                  1
# 128                                                  1
#
#                                      Pool Filenames.31  \
# 0                                               H4K5ac
# 1                                                    3
# 2    UCSD.IMR90.H4K5ac.LL234.bed.gz;UCSD.IMR90.H4K5...
# 3                                                  NaN
# 4    UCSD.H9.H4K5ac.YL240.bed.gz;UCSD.H9.H4K5ac.SK2...
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
#
#                                      Pool Filenames.32  \
# 0                                             H3K23me2
# 1                                                    2
# 2                                                  NaN
# 3                                                  NaN
# 4    UCSD.H9.H3K23me2.SK527.bed.gz;UCSD.H9.H3K23me2...
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
#
#                                      Pool Filenames.33  \
# 0                                              H2AK9ac
# 1                                                    1
# 2    UCSD.IMR90.H2AK9ac.AY6.bed.gz;UCSD.IMR90.H2AK9...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                NaN
#
#                                      Pool Filenames.34  \
# 0                                              H3K9me1
# 1                                                    4
# 2    UCSD.IMR90.H3K9me1.SK12.bed.gz;UCSD.IMR90.H3K9...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 124                                                NaN
# 125                                                NaN
# 126                                               E127
# 127                                                NaN
# 128                                                NaN
#
#                 Pool Filenames.35 Pool Filenames.36
# 0                         H3T11ph           H4K12ac
# 1                               2                 1
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4    UCSD.H9.H3T11ph.SK509.bed.gz               NaN
# ..                            ...               ...
# 124                           NaN               NaN
# 125                           NaN               NaN
# 126                           NaN               NaN
# 127                           NaN               NaN
# 128                           NaN               NaN
#
# [129 rows x 95 columns]

# %%
df_raw.columns
# Out:
# Index(['Comments', 'Epigenome ID (EID)', 'ORDER', 'GROUP', 'COLOR',
#        'Epigenome Mnemonic', 'Under Seq', 'Quality Rating',
#        'Auto Use Train (Core)', 'Manual Use Train (Core)', 'Has K27ac',
#        'Train Core + K27ac', 'Core + Ac + DNase + 9 Class1 Marks',
#        'Core + Ac + DNase + 13 Class1 Marks', 'Standardized Epigenome name',
#        'Epigenome name (from EDACC Release 9 directory)', 'ANATOMY', 'TYPE',
#        'LAB (Based on 5 core histone marks only)',
#        'AGE (Post Birth in YEARS/ Fetal in GESTATIONAL WEEKS/CELL LINE CL) ',
#        'SEX (Male, Female, Mixed, Unknown)', 'SOLID / LIQUID', 'ETHNICITY',
#        'Single Donor (SD) /Composite (C)', 'DONOR / SAMPLE ALIAS', 'CLASS',
#        'Unnamed: 26', 'Pool Filenames', 'Pool Filenames.1', 'Pool Filenames.2',
#        'Pool Filenames.3', 'Pool Filenames.4', 'Pool Filenames.5',
#        'Pool Filenames.6', 'Pool Filenames.7', 'Pool Filenames.8',
#        'Pool Filenames.9', 'Pool Filenames.10', 'Pool Filenames.11',
#        'Pool Filenames.12', 'Unnamed: 40', 'Nreads (36bp) 30M',
#        'Nreads (36bp) 30M.1', 'Nreads (36bp) 30M.2', 'Nreads (36bp) 30M.3',
#        'Nreads (36bp) 30M.4', 'Nreads (36bp) 30M.5', 'Nreads (36bp) 30M.6',
#        'Nreads (36bp) 30M.7', 'Nreads (36bp) 50M', 'Unnamed: 50',
#        'NSC (Signal to noise)', 'NSC (Signal to noise).1',
#        'NSC (Signal to noise).2', 'NSC (Signal to noise).3',
#        'NSC (Signal to noise).4', 'NSC (Signal to noise).5',
#        'NSC (Signal to noise).6', 'NSC (Signal to noise).7',
#        'NSC (Signal to noise).8', 'Unnamed: 60', 'RSC (Phantom Peak)',
#        'RSC (Phantom Peak).1', 'RSC (Phantom Peak).2', 'RSC (Phantom Peak).3',
#        'RSC (Phantom Peak).4', 'RSC (Phantom Peak).5', 'RSC (Phantom Peak).6',
#        'RSC (Phantom Peak).7', 'RSC (Phantom Peak).8', 'Unnamed: 70',
#        'Pool Filenames.13', 'Pool Filenames.14', 'Pool Filenames.15',
#        'Pool Filenames.16', 'Pool Filenames.17', 'Pool Filenames.18',
#        'Pool Filenames.19', 'Pool Filenames.20', 'Pool Filenames.21',
#        'Pool Filenames.22', 'Pool Filenames.23', 'Pool Filenames.24',
#        'Pool Filenames.25', 'Pool Filenames.26', 'Pool Filenames.27',
#        'Pool Filenames.28', 'Pool Filenames.29', 'Pool Filenames.30',
#        'Pool Filenames.31', 'Pool Filenames.32', 'Pool Filenames.33',
#        'Pool Filenames.34', 'Pool Filenames.35', 'Pool Filenames.36'],
#       dtype='object')

# %%
df_sel=df_raw[["Epigenome ID (EID)","GROUP","ANATOMY","TYPE","Standardized Epigenome name"]]

# %%
df=df_sel.dropna()
df
# Out:
#     Epigenome ID (EID)       GROUP ANATOMY            TYPE  \
# 2                 E017       IMR90    LUNG        CellLine
# 3                 E002         ESC     ESC  PrimaryCulture
# 4                 E008         ESC     ESC  PrimaryCulture
# 5                 E001         ESC     ESC  PrimaryCulture
# 6                 E015         ESC     ESC  PrimaryCulture
# ..                 ...         ...     ...             ...
# 124               E125  ENCODE2012   BRAIN  PrimaryCulture
# 125               E126  ENCODE2012    SKIN  PrimaryCulture
# 126               E127  ENCODE2012    SKIN  PrimaryCulture
# 127               E128  ENCODE2012    LUNG  PrimaryCulture
# 128               E129  ENCODE2012    BONE  PrimaryCulture
#
#                        Standardized Epigenome name
# 2           IMR90 fetal lung fibroblasts Cell Line
# 3                                     ES-WA7 Cells
# 4                                         H9 Cells
# 5                                      ES-I3 Cells
# 6                                      HUES6 Cells
# ..                                             ...
# 124                  NH-A Astrocytes Primary Cells
# 125  NHDF-Ad Adult Dermal Fibroblast Primary Cells
# 126      NHEK-Epidermal Keratinocyte Primary Cells
# 127             NHLF Lung Fibroblast Primary Cells
# 128                       Osteoblast Primary Cells
#
# [127 rows x 5 columns]

# %%
df[df["ANATOMY"]=="LUNG"]
# Out:
#     Epigenome ID (EID)       GROUP ANATOMY            TYPE  \
# 2                 E017       IMR90    LUNG        CellLine
# 104               E088       Other    LUNG   PrimaryTissue
# 111               E096       Other    LUNG   PrimaryTissue
# 113               E114  ENCODE2012    LUNG        CellLine
# 127               E128  ENCODE2012    LUNG  PrimaryCulture
#
#                     Standardized Epigenome name
# 2        IMR90 fetal lung fibroblasts Cell Line
# 104                                  Fetal Lung
# 111                                        Lung
# 113  A549 EtOH 0.02pct Lung Carcinoma Cell Line
# 127          NHLF Lung Fibroblast Primary Cells

# %%
df[df["ANATOMY"]=="LIVER"]
# Out:
#     Epigenome ID (EID)       GROUP ANATOMY           TYPE  \
# 109               E066       Other   LIVER  PrimaryTissue
# 117               E118  ENCODE2012   LIVER       CellLine
#
#                   Standardized Epigenome name
# 109                                     Liver
# 117  HepG2 Hepatocellular Carcinoma Cell Line

# %%
df[df["ANATOMY"]=="BRAIN"]
# Out:
#     Epigenome ID (EID)       GROUP ANATOMY            TYPE  \
# 61                E054    Neurosph   BRAIN  PrimaryCulture
# 62                E053    Neurosph   BRAIN  PrimaryCulture
# 65                E071       Brain   BRAIN   PrimaryTissue
# 66                E074       Brain   BRAIN   PrimaryTissue
# 67                E068       Brain   BRAIN   PrimaryTissue
# 68                E069       Brain   BRAIN   PrimaryTissue
# 69                E072       Brain   BRAIN   PrimaryTissue
# 70                E067       Brain   BRAIN   PrimaryTissue
# 71                E073       Brain   BRAIN   PrimaryTissue
# 72                E070       Brain   BRAIN   PrimaryTissue
# 73                E082       Brain   BRAIN   PrimaryTissue
# 74                E081       Brain   BRAIN   PrimaryTissue
# 124               E125  ENCODE2012   BRAIN  PrimaryCulture
#
#                            Standardized Epigenome name
# 61   Ganglion Eminence derived primary cultured neu...
# 62        Cortex derived primary cultured neurospheres
# 65                            Brain Hippocampus Middle
# 66                              Brain Substantia Nigra
# 67                              Brain Anterior Caudate
# 68                               Brain Cingulate Gyrus
# 69                        Brain Inferior Temporal Lobe
# 70                                 Brain Angular Gyrus
# 71                Brain_Dorsolateral_Prefrontal_Cortex
# 72                               Brain Germinal Matrix
# 73                                  Fetal Brain Female
# 74                                    Fetal Brain Male
# 124                      NH-A Astrocytes Primary Cells
